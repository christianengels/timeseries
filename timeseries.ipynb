# %% [markdown]
# # Time Series Stuff: Basic Stochastic Processes

# %%
import stoch_proc as sp
import pylab as pl

# %%
random_walk = sp.sp(length=1000, mu = 0, alpha = 1)

# %%
pl.plot(random_walk)

# %%
rolling_mean = random_walk.copy()
sp.rmean(rolling_mean)
pl.plot(rolling_mean)

# %%
sp.sp_many(length=100, rep=10, mu=0, alpha=1)
